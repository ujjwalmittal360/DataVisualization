# %%
a = float(input("Enter first number: "))
b = float(input("Enter first number: "))
c = float(input("Enter first number: "))
sum = a + b + c
print("The sum of three number is:", sum)
# Out:
# Enter first number: 25.5
# Enter first number: 29.6
# Enter first number: 89.1
# The sum of three number is: 144.2

# %%
str1 = "ABC"
str2 = "XYZ"
str3 = "UVW"
result = str1 + str2 + str3
print("Concatenated string:", result)
# Out:
# Concatenated string: ABCXYZUVW

# %%
print("Table of 7:")
for i in range(1, 11):
    print("7 x", i, "=", 7 * i)


print("Table of 9:")
for i in range(1, 11):
    print("9 x", i, "=", 9 * i)
# Out:
# Table of 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# Table of 9:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %%
n = int(input("Enter a number: "))
for i in range(1, 11):
    print(n, "x", i, "=", n * i)
# Out:
# Enter a number: 4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
n = int(input("Enter a number: "))
total = 0
for i in range(1, n + 1):
    total += i
print("Sum from 1 to", n, "is:", total)
# Out:
# Enter a number: 25
# Sum from 1 to 25 is: 325

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
print("Maximum is:", max(a, b, c))
# Out:
# Enter first number: 10
# Enter second number: 30
# Enter third number: 70
# Maximum is: 70

# %%
n = int(input("Enter a number: "))
total = 0
for i in range(1, n + 1):
    if i % 7 == 0 and i % 9 == 0:
        total += i
print("Sum of numbers divisible by 7 and 9:", total)
# Out:
# Enter a number: 100
# Sum of numbers divisible by 7 and 9: 63

# %%
n = int(input("Enter a number: "))
total = 0
for i in range(2, n + 1):
    is_prime = True
    for j in range(2, int(i ** 0.5) + 1):
        if i % j == 0:
            is_prime = False
            break
    if is_prime:
        total += i
print("Sum of prime numbers from 1 to", n, "is:", total)
# Out:
# Enter a number: 24
# Sum of prime numbers from 1 to 24 is: 100

# %%
def sum_of_odds(n):
    total = 0
    for i in range(1, n + 1, 2):
        total += i
    return total

n = int(input("Enter a number: "))
print("Sum of odd numbers from 1 to", n, "is:", sum_of_odds(n))
# Out:
# Enter a number: 25
# Sum of odd numbers from 1 to 25 is: 169

# %%
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

def sum_of_primes(n):
    total = 0
    for i in range(2, n + 1):
        if is_prime(i):
            total += i
    return total

n = int(input("Enter a number: "))
print("Sum of prime numbers from 1 to", n, "is:", sum_of_primes(n))
# Out:
# Enter a number: 75
# Sum of prime numbers from 1 to 75 is: 712
